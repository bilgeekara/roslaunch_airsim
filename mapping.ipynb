# %%
#from mpl_toolkits import mplot3d

# %%
#x = [24,-13,34,10,-15,42]
#y = [33,2,-27,8,-1,34]
#z = [33,30,36,39,30,24]

# %%
#fig = plt.figure(figsize = (12, 8))
#ax = plt.axes(projection='3d')

#zdata = z
#xdata = x
#ydata = y

#p=ax.scatter3D(xdata, ydata, zdata, color='blue');
#plt.title("HAREKET HALİNDEKİ İHA KONUMLARI")
#ax.set_xlabel('X-axis', fontweight ='bold')
#ax.set_ylabel('Y-axis', fontweight ='bold')
#ax.set_zlabel('Z-axis', fontweight ='bold')

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x= [85,-129.9,30.1,85,30.1,85,30.1,-75,-129.9,-129.9,30.1, -75,-25,-25,30.1]
y=[-142.6,-142.8,-142.8,-92.6,-92.6,77.2,77.2,77.2, 77.2,-27.7,-27.6,-27.6,-27.6,27.5,27.5]
# x ekseninkedki veriler ve y eksenindekileri for döngüsüne sok ve yeni listeler elde et liselerde x ve y çiftler halinde bulunacak bunları plat yap her bir for döngüsünde böylece tüm senoryaları

# %%
plt.figure(figsize=(15,12))
s = [150]
plt.scatter([-85,-85,-85,-30.1,75],[-142.6,-92.6,77.2,77.2,77.2],label ='wp konumları',s=s,c = 'blue')
plt.scatter([129.9,129.9,129.9,-30.1,-30.1],[77.2,-27.6,-142.8,-142.8,-92.6],s=s,c = 'blue')
plt.scatter([-30.1,-30.1,25,25,75],[-27.7,27.5,27.5,-27.6,-27.6] ,s=s,c = 'blue')
plt.plot([-85,-85,-85,-30.1,75],[-142.6,-92.6,77.2,77.2,77.2],color = 'k')
plt.plot([129.9,129.9,129.9,-30.1,-30.1],[77.2,-27.6,-142.8,-142.8,-92.6],color = 'k')
plt.plot([-30.1,-30.1,25,25,75],[-27.7,27.5,27.5,-27.6,-27.6],color = 'k')

plt.plot([75,75],[77.2,-27.6],color = 'k', label= 'yol')
plt.plot([75,129.9],[77.2,77.2],color = 'k')
plt.plot([-30.1,25],[-27.7,-27.6],color = 'k')
plt.plot([-30.1,-30.1],[77.2,-92.6],color = 'k')
plt.plot([-85,-30.1],[-92.6,-92.6],color = 'k')
plt.plot([-30.1,-85],[-142.8,-142.6],color = 'k')
plt.plot([129.9,75],[-27.6,-27.6],color = 'k')

plt.scatter([59.64,-8.35,-29.95,-29.95,-29.95,75.14,130.14,54.24,-84.95,14.64,7.94,130.14],[-27.64,-27.44,21.25,-59.44,-118.24,35.14,-109.94,-142.54,-118.24,-142.54,27.35,49.25],label = 'hasta konumları',s=s,c='red')
plt.scatter([0],[-27.7],label = 'başlangıç noktası',s=s,c='magenta')
plt.scatter([-64.1,83.9],[-92.6,77.2],label = 'şarj istasyonu',s=s,c='orange',marker='^')
plt.scatter([74.9,-84.75],[-1.24,-63],label = 'hastane konumları',s=s,c='green',marker='^')

#plt.plot([0,-29.95],[-27.7,21.25], '-.' , label= 'rota',color = 'grey')

plt.arrow(x=0, y=-27.7, dx=-27.7, dy=46, width=1.08, facecolor='yellow')
plt.annotate('yer değiştirme vektörü', xy = (-20, 13), fontsize=13)





#plt.legend(prop={"size":13})
plt.title('Simülasyon Ortamı Yol Haritası',fontsize=20)
plt.xlabel('X Ekseni',fontsize=20)
plt.ylabel('Y Ekseni',fontsize=20)
#plt.plot([85+5,85+5,85+5,30.1+5,-75+5],[-142.6+5,-92.6+5,77.2+5,77.2+5,77.2+5])
#plt.plot([-129.9+5,-129.9+5,-129.9+5,30.1+5,30.1+5],[77.2+5,-27.6+5,-142.8+5,-142.8+5,-92.6+5])
#plt.plot([30.1+5,30.1+5,-25+5,-25+5,-75+5],[-27.7+5,27.5+5,27.5+5,-27.6+5,-27.6+5])

#plt.plot([85-5,85-5,85-5,30.1-5,-75-5],[-142.6-5,-92.6-5,77.2-5,77.2-5,77.2-5])
#plt.plot([-129.9-5,-129.9-5,-129.9-5,30.1-5,30.1-5],[77.2-5,-27.6-5,-142.8-5,-142.8-5,-92.6-5])
#plt.plot([30.1-5,30.1-5,-25-5,-25-5,-75-5],[-27.7-5,27.5-5,27.5-5,-27.6-5,-27.6-5])
#plt.plot([-75,-129.9],[77.2,77.2])
#plt.plot([30.1,30.1],[-92.6,-27.7])
#plt.plot([30.1,85],[-92.6,-92.6])
#plt.plot([85,-129.9,30.1],[-142.8,-142.8,-142.8])
#plt.plot(x,y)
#plt.plot([0,-75.14],[-27.7,35.14])
# Out:
# Text(0, 0.5, 'Y Ekseni')
